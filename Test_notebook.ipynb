# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import testStreamingSvd

# %%
dat = testStreamingSvd.generateTimeSeriesData()

# %%
plt.plot(dat.T);
# Out:
# <img src="data:image/png;base64,...">

# %%
import streamingSvd as algo

# %%
Q = algo.getSvd(dat, 3, 1, 1000)

# %%
Q
# Out:
# array([[ 0.88001431,  0.04407331,  0.47289783],
#        [-0.0480064 ,  0.99883997, -0.00375529],
#        [-0.47251476, -0.01939742,  0.88110927]])

# %%
U, S, V = np.linalg.svd(dat, full_matrices=False)
U
# Out:
# array([[-0.88062013,  0.04448118, -0.47173044],
#        [ 0.04827296,  0.9988259 ,  0.00406759],
#        [ 0.47135751, -0.01918982, -0.88173343]])

# %%
dat = testStreamingSvd.generateARdata()

# %%
plt.plot(dat.T);
# Out:
# <img src="data:image/png;base64,...">

# %%
dat = np.loadtxt('AR.dat')

# %%
plt.plot(dat.T);
# Out:
# <img src="data:image/png;base64,...">
