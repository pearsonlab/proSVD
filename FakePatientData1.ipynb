# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import testStreamingSvd as test
import streamingSvd as algo

# %%
dat = test.generateFakePatientData(10,1000)

# %%
plt.figure(1)
plt.plot(dat.T);
# Out:
# <img src="data:image/png;base64,...">
