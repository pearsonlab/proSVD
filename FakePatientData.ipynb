# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import testStreamingSvd as test
import streamingSvd as algo

# %%
dat = test.generateFakePatientData(3,1000)

# %%
plt.figure(1)
plt.plot(dat.T);
# Out:
# <img src="data:image/png;base64,...">

# %%
 t = np.linspace(0, 10*np.pi, 100, endpoint=False)

# %%
y_sin = np.sin(t)

# %%
plt.figure(2)
plt.plot(t,y_sin)
# Out:
# <img src="data:image/png;base64,...">
